# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load

# %%
def load_data(file_name):
    default_dir = "ch6/nobel_winners/data/"
    df = pd.read_json(open(default_dir + file_name))
    return df

# %%
df = load_data('nobel_winners_full.json')

# %% [markdown]
# ## Basic exploration

# %%
df.info()

# %%
df.describe()

# %%
df.describe(include=['object'])

# %%
df.head(5)

# %%
set(df.born_in.apply(type))

# %%
df[df.name.str.contains('\*')]['name']

# %% [markdown]
# ## Remove * from names

# %%
df.name = df.name.str.replace('*', '')
df.name = df.name.str.strip()

# %%
df[df.name.str.contains('\*')]['name']

# %% [markdown]
# ## Replace "" with np.nan

# %%
df.replace("", np.nan, inplace=True)

# %% [markdown]
# ## Save "born in" information to another table

# %%
df_born = df[df.born_in.notnull()][["name", "year", "born_in", "text"]]
df_born.head()

# %% [markdown]
# Some information of the "born_in" column is wrong. For example, Aaron Klug was born in Litthuania actually. Howerver, I'll ignore them.

# %%
df_born[df_born.duplicated(subset=["name", "year"], keep=False)].sort_values("name")

# %% [markdown]
# ## Check duplicated rows

# %%
df[df.duplicated(subset=['name', 'year'], keep=False)].sort_values('name')[['name', 'year', 'country', 'born_in', 'text']]

# %% [markdown]
# ## Reindex and drop duplicates

# %%
df = df.reindex(np.random.permutation(df.index)).sort_values("born_in")
df = df.drop_duplicates(['name', 'year'], keep='last')
df = df.sort_index()
df.count()

# %%
df[df.born_in.notnull()]

# %%
df[df.duplicated(subset=['name'], keep=False)].sort_values('name')[['name', 'year', 'country']]

# %% [markdown]
# ## Fix errors manually

# %%
df = df[~((df.name=='Henry Kissinger') & (df.year==1978))]
df = df[~((df.name=='Ragnar Granit') & (df.year==1809))]
df = df[~(df.name=='Marie Curie')]

# %%
df[df.year==1809]

# %%
df.loc[df.name=='Artturi Ilmari Virtanen', 'year'] = 1945
df.loc[df.name=='Frans Eemil Sillanpää', 'year'] = 1939

# %%
df[df.country=='Finland'][["name", "year"]]

# %%
df.loc[(df.name=='Marie Skłodowska-Curie') & (df.year==1911), 'country'] = 'France'

# %%
df[df.duplicated(subset=['name'], keep=False)].sort_values('name')[['name', 'year', 'country']]

# %% [markdown]
# ## Dealing with missing fields

# %%
df.count()

# %%
df[df.category.isnull()][['name', 'text']]

# %%
df.loc[df.name=='Andrew Schally', 'category'] = 'Physiology or Medicine'
df.loc[df.name=='Róbert Bárány', 'category'] = 'Physiology or Medicine'
df.loc[df.name=='Alexis Carrel', 'category'] = 'Physiology or Medicine'
df.loc[df.name=='Amartya Sen', 'category'] = 'Economics'

# %%
df[df.gender.isnull()]['name']

# %%
df = df[df.gender.notnull()]

# %%
df.count()

# %% [markdown]
# ## Dealing with times and dates

# %%
with_death_dates = df[df.date_of_death.notnull()]
bad_dates = pd.isnull(pd.to_datetime(with_death_dates.date_of_death, errors='coerce'))
with_death_dates[bad_dates][['name', 'date_of_death']]

# %%
bad_dates = pd.isnull(pd.to_datetime(df.date_of_birth, errors='coerce'))
df[bad_dates][['name', 'date_of_birth']]

# %%
df.date_of_death = pd.to_datetime(df.date_of_death, errors='raise')

# %%
df.date_of_birth = pd.to_datetime(df.date_of_birth, errors='raise')

# %%
df.info()

# %% [markdown]
# ## Generate the "award age" field

# %%
df['award_age'] = df.year - pd.DatetimeIndex(df.date_of_birth).year

# %%
df.sort_values(['award_age', 'year']).iloc[:15][['name', 'award_age', 'category', 'year']]

# %% [markdown]
# ## The full function to clean data

# %%
def clean_data(df):
    
    df.name = df.name.str.replace('*', '')
    df.name = df.name.str.strip()

    df.replace("", np.nan, inplace=True)

    df_born = df[df.born_in.notnull()][["name", "year", "born_in", "text"]]

    df = df.reindex(np.random.permutation(df.index)).sort_values("born_in")
    df = df.drop_duplicates(['name', 'year'], keep='last')
    df = df.sort_index()

    df = df[~((df.name=='Henry Kissinger') & (df.year==1978))]
    df = df[~((df.name=='Ragnar Granit') & (df.year==1809))]
    df = df[~(df.name=='Marie Curie')]

    df.loc[df.name=='Artturi Ilmari Virtanen', 'year'] = 1945
    df.loc[df.name=='Frans Eemil Sillanpää', 'year'] = 1939

    df.loc[(df.name=='Marie Skłodowska-Curie') & (df.year==1911), 'country'] = 'France'

    df.loc[df.name=='Andrew Schally', 'category'] = 'Physiology or Medicine'
    df.loc[df.name=='Róbert Bárány', 'category'] = 'Physiology or Medicine'
    df.loc[df.name=='Alexis Carrel', 'category'] = 'Physiology or Medicine'
    df.loc[df.name=='Amartya Sen', 'category'] = 'Economics'

    df = df[df.gender.notnull()]

    df.date_of_death = pd.to_datetime(df.date_of_death, errors='raise')
    df.date_of_birth = pd.to_datetime(df.date_of_birth, errors='raise')
    df['award_age'] = df.year - pd.DatetimeIndex(df.date_of_birth).year

    return df, df_born

# %%
df = load_data('nobel_winners_full.json')
df_clean, df_born = clean_data(df)

# %%
df_clean.sort_values(['award_age', 'year']).iloc[:15][['name', 'award_age', 'category', 'year']]
# Out:
#                         name  award_age                category  year
# 670         Malala Yousafzai         17                   Peace  2014
# 419   William Lawrence Bragg         25                 Physics  1915
# 712              Nadia Murad         25                   Peace  2018
# 513     Georges J. F. Köhler         30  Physiology or Medicine  1976
# 858   Werner Karl Heisenberg         31                 Physics  1932
# 415               Paul Dirac         31                 Physics  1933
# 46             Carl Anderson         31                 Physics  1936
# 99             Tsung-Dao Lee         31                 Physics  1957
# 1040    Frederick G. Banting         32  Physiology or Medicine  1923
# 894         Rudolf Mössbauer         32                 Physics  1961
# 471         Mairead Corrigan         32                   Peace  1976
# 35           Tawakkol Karman         32                   Peace  2011
# 125         Joshua Lederberg         33  Physiology or Medicine  1958
# 456    Brian David Josephson         33                 Physics  1973
# 472           Betty Williams         33                   Peace  1976

# %% [markdown]
# ## Merging dataframes

# %%
df_winners_bio = load_data('winners_bio.json')

# %%
df_winners_bio.head()
# Out:
#                                            bio_image  \
# 0  full/9daaecfcf8bb7105837943d03ddcfb665cfd8397.jpg
# 1  full/4cb2c33a5dc3682f935daf59d6fcff61eb43b781.jpg
# 2  full/5ac06410e54227219a7b467108cb0875ee78064b.jpg
# 3  full/56bd02cfd357fc0e86688eb3c78c0baef4cf10bb.jpg
# 4  full/47410cd8d1ce6ce5c6e8c073f5d7347c5db59a22.jpg
#
#                                           image_urls  \
# 0  [https://upload.wikimedia.org/wikipedia/common...
# 1  [https://upload.wikimedia.org/wikipedia/common...
# 2  [https://upload.wikimedia.org/wikipedia/en/thu...
# 3  [https://upload.wikimedia.org/wikipedia/common...
# 4  [https://upload.wikimedia.org/wikipedia/common...
#
#                                                 link  \
# 0  https://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# 1          https://en.wikipedia.org/wiki/Fritz_Pregl
# 2  https://en.wikipedia.org/wiki/Richard_Adolf_Zs...
# 3  https://en.wikipedia.org/wiki/Julius_Wagner-Ja...
# 4     https://en.wikipedia.org/wiki/Karl_Landsteiner
#
#                                             mini_bio
# 0  César Milstein, CH, FRS (8 October 1927 – 24 M...
# 1
# 2
# 3
# 4  Karl Landsteiner, ForMemRS, (14 June 1868 – 26...

# %%
df_clean.head()
# Out:
#   born_in                category  country date_of_birth date_of_death gender  \
# 2     NaN                 Physics  Austria    1883-06-24    1964-12-17   male
# 3     NaN                 Physics  Austria    1887-08-12    1961-01-04   male
# 4     NaN               Chemistry  Austria    1914-05-19    2002-02-06   male
# 5     NaN                 Physics  Austria    1900-04-25    1958-12-15   male
# 6     NaN  Physiology or Medicine  Denmark    1911-12-23    1994-10-07   male
#
#                                                 link                 name  \
# 2  https://en.wikipedia.org/wiki/Victor_Francis_Hess  Victor Francis Hess
# 3  https://en.wikipedia.org/wiki/Erwin_Schr%C3%B6...    Erwin Schrödinger
# 4           https://en.wikipedia.org/wiki/Max_Perutz           Max Perutz
# 5       https://en.wikipedia.org/wiki/Wolfgang_Pauli       Wolfgang Pauli
# 6      https://en.wikipedia.org/wiki/Niels_Kaj_Jerne      Niels Kaj Jerne
#
#      place_of_birth     place_of_death  \
# 2  Deutschfeistritz       Mount Vernon
# 3            Vienna             Vienna
# 4            Vienna          Cambridge
# 5            Vienna             Zürich
# 6            London  Castillon-du-Gard
#
#                                              text  year  award_age
# 2             Victor Francis Hess , Physics, 1936  1936         53
# 3               Erwin Schrödinger , Physics, 1933  1933         46
# 4                    Max Perutz , Chemistry, 1962  1962         48
# 5                  Wolfgang Pauli , Physics, 1945  1945         45
# 6  Niels Kaj Jerne , Physiology or Medicine, 1984  1984         73

# %%
df_winners_all = pd.merge(df_clean, df_winners_bio, how='outer', on='link')

# %%
df_winners_all.count()
# Out:
# born_in             33
# category          1110
# country           1077
# date_of_birth     1110
# date_of_death      750
# gender            1110
# link              1124
# name              1110
# place_of_birth    1110
# place_of_death     750
# text              1110
# year              1110
# award_age         1110
# bio_image         1096
# image_urls        1124
# mini_bio          1124
# dtype: int64

# %%
df_winners_all = df_winners_all[~df_winners_all.name.isnull()].drop_duplicates(['link', 'year'])

# %%
df_winners_all.count()
# Out:
# born_in            21
# category          920
# country           899
# date_of_birth     920
# date_of_death     625
# gender            920
# link              920
# name              920
# place_of_birth    920
# place_of_death    625
# text              920
# year              920
# award_age         920
# bio_image         899
# image_urls        920
# mini_bio          920
# dtype: int64

# %%
df_winners_all[df_winners_all.bio_image.isnull()]
# Out:
#      born_in                category         country date_of_birth  \
# 191      NaN  Physiology or Medicine   United States    1918-01-23
# 212      NaN  Physiology or Medicine   United States    1903-12-19
# 217      NaN  Physiology or Medicine   United States    1924-02-23
# 256      NaN               Chemistry   United States    1919-04-22
# 286      NaN               Economics   United States    1927-08-24
# 337      NaN               Economics   United States    1937-09-15
# 338      NaN  Physiology or Medicine   United States    1947-05-08
# 340      NaN               Chemistry   United States    1941-04-28
# 351      NaN  Physiology or Medicine   United States    1939-10-30
# 366      NaN                 Physics   United States    1949-08-31
# 410      NaN  Physiology or Medicine   United States    1950-11-03
# 516      NaN                 Physics  United Kingdom    1924-05-11
# 524      NaN  Physiology or Medicine  United Kingdom    1911-03-26
# 533      NaN                   Peace  United Kingdom    1944-01-27
# 547      NaN               Economics  United Kingdom    1936-07-05
# 639      NaN  Physiology or Medicine          Sweden    1934-05-21
# 893      NaN               Chemistry         Germany    1943-09-30
# 947      NaN               Chemistry         Germany    1918-11-10
# 1007     NaN                   Peace          France    1887-02-05
# 1068     NaN               Chemistry          Canada    1929-01-23
# 1080     NaN              Literature          Canada    1931-07-10
#
#      date_of_death  gender                                               link  \
# 191     1999-02-21  female    https://en.wikipedia.org/wiki/Gertrude_B._Elion
# 212     1996-06-06    male   https://en.wikipedia.org/wiki/George_Davis_Snell
# 217     1998-05-07    male  https://en.wikipedia.org/wiki/Allan_McLeod_Cor...
# 256     2001-06-17    male       https://en.wikipedia.org/wiki/Donald_J._Cram
# 286            NaT    male   https://en.wikipedia.org/wiki/Harry_M._Markowitz
# 337            NaT    male    https://en.wikipedia.org/wiki/Robert_Lucas,_Jr.
# 338            NaT    male    https://en.wikipedia.org/wiki/H._Robert_Horvitz
# 340            NaT    male   https://en.wikipedia.org/wiki/K._Barry_Sharpless
# 351            NaT    male   https://en.wikipedia.org/wiki/Leland_H._Hartwell
# 366            NaT    male    https://en.wikipedia.org/wiki/H._David_Politzer
# 410            NaT    male        https://en.wikipedia.org/wiki/James_Rothman
# 516            NaT    male        https://en.wikipedia.org/wiki/Antony_Hewish
# 524     2003-04-20    male         https://en.wikipedia.org/wiki/Bernard_Katz
# 533            NaT  female      https://en.wikipedia.org/wiki/Mairead_Maguire
# 547     2018-08-29    male    https://en.wikipedia.org/wiki/James_A._Mirrlees
# 639            NaT    male  https://en.wikipedia.org/wiki/Bengt_I._Samuelsson
# 893            NaT    male   https://en.wikipedia.org/wiki/Johann_Deisenhofer
# 947     2007-07-23    male   https://en.wikipedia.org/wiki/Ernst_Otto_Fischer
# 1007    1976-02-20    male     https://en.wikipedia.org/wiki/Ren%C3%A9_Cassin
# 1068           NaT    male         https://en.wikipedia.org/wiki/John_Polanyi
# 1080           NaT  female          https://en.wikipedia.org/wiki/Alice_Munro
#
#                      name place_of_birth place_of_death  \
# 191     Gertrude B. Elion  New York City    Chapel Hill
# 212       George D. Snell       Bradford     Bar Harbor
# 217      Allan M. Cormack   Johannesburg     Winchester
# 256        Donald J. Cram        Chester    Palm Desert
# 286    Harry M. Markowitz        Chicago            NaN
# 337          Robert Lucas         Yakima            NaN
# 338     H. Robert Horvitz        Chicago            NaN
# 340    K. Barry Sharpless   Philadelphia            NaN
# 351    Leland H. Hartwell    Los Angeles            NaN
# 366     H. David Politzer  New York City            NaN
# 410         James Rothman      Haverhill            NaN
# 516         Antony Hewish          Fowey            NaN
# 524          Bernard Katz        Leipzig         London
# 533      Mairead Corrigan        Belfast            NaN
# 547     James A. Mirrlees      Minnigaff      Cambridge
# 639   Bengt I. Samuelsson       Halmstad            NaN
# 893    Johann Deisenhofer   Zusamaltheim            NaN
# 947    Ernst Otto Fischer          Solln         Munich
# 1007          René Cassin        Bayonne          Paris
# 1068         John Polanyi         Berlin            NaN
# 1080          Alice Munro        Wingham            NaN
#
#                                                    text    year  award_age  \
# 191    Gertrude B. Elion , Physiology or Medicine, 1988  1988.0       70.0
# 212      George D. Snell , Physiology or Medicine, 1980  1980.0       77.0
# 217   Allan M. Cormack ,  born in South Africa , Phy...  1979.0       55.0
# 256                    Donald J. Cram , Chemistry, 1987  1987.0       68.0
# 286                Harry M. Markowitz , Economics, 1990  1990.0       63.0
# 337                 Robert Lucas, Jr. , Economics, 1995  1995.0       58.0
# 338    H. Robert Horvitz , Physiology or Medicine, 2002  2002.0       55.0
# 340                K. Barry Sharpless , Chemistry, 2001  2001.0       60.0
# 351   Leland H. Hartwell , Physiology or Medicine, 2001  2001.0       62.0
# 366                   H. David Politzer , Physics, 2004  2004.0       55.0
# 410        James Rothman , Physiology or Medicine, 2013  2013.0       63.0
# 516                       Antony Hewish , Physics, 1974  1974.0       50.0
# 524   Bernard Katz ,  born in Germany , Physiology o...  1970.0       59.0
# 533                      Mairead Corrigan , Peace, 1976  1976.0       32.0
# 547                 James A. Mirrlees , Economics, 1996  1996.0       60.0
# 639   Bengt I. Samuelsson , Physiology or Medicine, ...  1982.0       48.0
# 893                Johann Deisenhofer , Chemistry, 1988  1988.0       45.0
# 947                Ernst Otto Fischer , Chemistry, 1973  1973.0       55.0
# 1007                          René Cassin , Peace, 1968  1968.0       81.0
# 1068  John Polanyi ,  born in Germany , Chemistry, 1986  1986.0       57.0
# 1080                     Alice Munro , Literature, 2013  2013.0       82.0
#
#      bio_image image_urls                                           mini_bio
# 191        NaN         []  Gertrude Belle Elion (January 23, 1918 – Febru...
# 212        NaN         []
# 217        NaN         []
# 256        NaN         []
# 286        NaN         []  Harry Max Markowitz (born August 24, 1927) is ...
# 337        NaN         []
# 338        NaN         []
# 340        NaN         []  Karl Barry Sharpless (born April 28, 1941) is ...
# 351        NaN         []  Leland Harrison (Lee) Hartwell (born October 3...
# 366        NaN         []  Hugh David Politzer (/ˈpɑːlɪtsər/; born August...
# 410        NaN         []  James Edward Rothman (November 3, 1950 – ) is ...
# 516        NaN         []  Antony Hewish FRS FInstP (born 11 May 1924) is...
# 524        NaN         []  Sir Bernard Katz, FRS (26 March 1911 – 20 Apri...
# 533        NaN         []  Mairead Maguire (born 27 January 1944), also k...
# 547        NaN         []  Sir James Alexander Mirrlees FRSE FBA (5 July ...
# 639        NaN         []
# 893        NaN         []
# 947        NaN         []
# 1007       NaN         []  René Samuel Cassin (5 October 1887 – 20 Februa...
# 1068       NaN         []  John Charles Polanyi, PC CC FRSC OOnt FRS (bor...
# 1080       NaN         []  Alice Ann Munro (/ˈælɪs ˌæn mʌnˈroʊ/, née Laid...

# %% [markdown]
# ## Saving the cleaned dataset

# %%
from tools.mongodb import *

# %%
df_to_mongo(df_clean, 'nobel_prize', 'winners')
df_to_mongo(df_born, 'nobel_prize', 'winners_born_in')
df_to_mongo(df_winners_all, 'nobel_prize', 'winners_all')

# %%
df_restore = mongo_to_df('nobel_prize', 'winners_all')
df_restore
# Out:
# 11   1965-01-24T00:00:00.000Z    male
# 12                       None    male
# 13                       None    male
# 14                       None    male
# 15   2015-06-02T00:00:00.000Z    male
# 16   2018-09-23T00:00:00.000Z    male
# 17                       None    male
# 18                       None  female
# 19                       None  female
# 20                       None  female
# 21                       None    male
# 22   2014-05-17T00:00:00.000Z    male
# 23   1985-07-08T00:00:00.000Z    male
# 24   1988-01-11T00:00:00.000Z    male
# 25   1937-02-07T00:00:00.000Z    male
# 26   1931-05-09T00:00:00.000Z    male
# 27   1919-01-06T00:00:00.000Z    male
# 28   1990-10-13T00:00:00.000Z    male
# 29                       None  female
# ..                        ...     ...
# 890                      None    male
# 891                      None    male
# 892                      None    male
# 893  1990-09-30T00:00:00.000Z    male
# 894                      None  female
# 895                      None    male
# 896                      None    male
# 897  2003-10-13T00:00:00.000Z    male
# 898  1997-05-02T00:00:00.000Z    male
# 899  1985-08-31T00:00:00.000Z    male
# 900  1968-02-21T00:00:00.000Z    male
# 901                      None  female
# 902                      None    male
# 903  1961-04-06T00:00:00.000Z    male
# 904  1943-05-14T00:00:00.000Z    male
# 905  1949-05-06T00:00:00.000Z    male
# 906  1912-10-06T00:00:00.000Z    male
# 907  2003-05-28T00:00:00.000Z    male
# 908  2013-05-04T00:00:00.000Z    male
# 909  1983-05-22T00:00:00.000Z    male
# 910  1969-01-30T00:00:00.000Z    male
# 911  1968-07-18T00:00:00.000Z    male
# 912                      None  female
# 913                      None    male
# 914                      None  female
# 915                      None    male
# 916                      None    male
# 917  1914-06-21T00:00:00.000Z  female
# 918  1989-02-27T00:00:00.000Z    male
# 919  1921-05-05T00:00:00.000Z    male
#
#                                             image_urls  \
# 0    [https://upload.wikimedia.org/wikipedia/common...
# 1    [https://upload.wikimedia.org/wikipedia/common...
# 2    [https://upload.wikimedia.org/wikipedia/common...
# 3    [https://upload.wikimedia.org/wikipedia/common...
# 4    [https://upload.wikimedia.org/wikipedia/common...
# 5    [https://upload.wikimedia.org/wikipedia/common...
# 6    [https://upload.wikimedia.org/wikipedia/common...
# 7    [https://upload.wikimedia.org/wikipedia/common...
# 8    [https://upload.wikimedia.org/wikipedia/common...
# 9    [https://upload.wikimedia.org/wikipedia/common...
# 10   [https://upload.wikimedia.org/wikipedia/common...
# 11   [https://upload.wikimedia.org/wikipedia/common...
# 12   [https://upload.wikimedia.org/wikipedia/common...
# 13   [https://upload.wikimedia.org/wikipedia/common...
# 14   [https://upload.wikimedia.org/wikipedia/common...
# 15   [https://upload.wikimedia.org/wikipedia/common...
# 16   [https://upload.wikimedia.org/wikipedia/common...
# 17   [https://upload.wikimedia.org/wikipedia/common...
# 18   [https://upload.wikimedia.org/wikipedia/common...
# 19   [https://upload.wikimedia.org/wikipedia/common...
# 20   [https://upload.wikimedia.org/wikipedia/common...
# 21   [https://upload.wikimedia.org/wikipedia/common...
# 22   [https://upload.wikimedia.org/wikipedia/common...
# 23   [https://upload.wikimedia.org/wikipedia/common...
# 24   [https://upload.wikimedia.org/wikipedia/common...
# 25   [https://upload.wikimedia.org/wikipedia/common...
# 26   [https://upload.wikimedia.org/wikipedia/common...
# 27   [https://upload.wikimedia.org/wikipedia/common...
# 28   [https://upload.wikimedia.org/wikipedia/common...
# 29   [https://upload.wikimedia.org/wikipedia/common...
# ..                                                 ...
# 890  [https://upload.wikimedia.org/wikipedia/common...
# 891  [https://upload.wikimedia.org/wikipedia/common...
# 892  [https://upload.wikimedia.org/wikipedia/common...
# 893  [https://upload.wikimedia.org/wikipedia/common...
# 894                                                 []
# 895  [https://upload.wikimedia.org/wikipedia/common...
# 896  [https://upload.wikimedia.org/wikipedia/common...
# 897  [https://upload.wikimedia.org/wikipedia/common...
# 898  [https://upload.wikimedia.org/wikipedia/common...
# 899  [https://upload.wikimedia.org/wikipedia/common...
# 900  [https://upload.wikimedia.org/wikipedia/common...
# 901  [https://upload.wikimedia.org/wikipedia/common...
# 902  [https://upload.wikimedia.org/wikipedia/common...
# 903  [https://upload.wikimedia.org/wikipedia/common...
# 904  [https://upload.wikimedia.org/wikipedia/common...
# 905  [https://upload.wikimedia.org/wikipedia/common...
# 906  [https://upload.wikimedia.org/wikipedia/common...
# 907  [https://upload.wikimedia.org/wikipedia/common...
# 908  [https://upload.wikimedia.org/wikipedia/common...
# 909  [https://upload.wikimedia.org/wikipedia/common...
# 910  [https://upload.wikimedia.org/wikipedia/common...
# 911  [https://upload.wikimedia.org/wikipedia/common...
# 912  [https://upload.wikimedia.org/wikipedia/common...
# 913  [https://upload.wikimedia.org/wikipedia/common...
# 914  [https://upload.wikimedia.org/wikipedia/common...
# 915  [https://upload.wikimedia.org/wikipedia/common...
# 916  [https://upload.wikimedia.org/wikipedia/common...
# 917  [https://upload.wikimedia.org/wikipedia/common...
# 918  [https://upload.wikimedia.org/wikipedia/common...
# 919  [https://upload.wikimedia.org/wikipedia/common...
#
#                                                   link  \
# 0    https://en.wikipedia.org/wiki/Victor_Francis_Hess
# 1    https://en.wikipedia.org/wiki/Erwin_Schr%C3%B6...
# 2             https://en.wikipedia.org/wiki/Max_Perutz
# 3         https://en.wikipedia.org/wiki/Wolfgang_Pauli
# 4        https://en.wikipedia.org/wiki/Niels_Kaj_Jerne
# 5    https://en.wikipedia.org/wiki/Johannes_Diderik...
# 6            https://en.wikipedia.org/wiki/Aziz_Sancar
# 7            https://en.wikipedia.org/wiki/Orhan_Pamuk
# 8        https://en.wikipedia.org/wiki/Georges_Charpak
# 9    https://en.wikipedia.org/wiki/Francis_William_...
# 10       https://en.wikipedia.org/wiki/Frederick_Soddy
# 11     https://en.wikipedia.org/wiki/Winston_Churchill
# 12          https://en.wikipedia.org/wiki/John_L._Hall
# 13        https://en.wikipedia.org/wiki/Roy_J._Glauber
# 14    https://en.wikipedia.org/wiki/Edward_C._Prescott
# 15            https://en.wikipedia.org/wiki/Irwin_Rose
# 16        https://en.wikipedia.org/wiki/Charles_K._Kao
# 17       https://en.wikipedia.org/wiki/George_E._Smith
# 18   https://en.wikipedia.org/wiki/Elizabeth_Blackburn
# 19      https://en.wikipedia.org/wiki/Carol_W._Greider
# 20         https://en.wikipedia.org/wiki/Toni_Morrison
# 21     https://en.wikipedia.org/wiki/Robert_Schrieffer
# 22        https://en.wikipedia.org/wiki/Gerald_Edelman
# 21
# 22
# 23   Kuznets made a decisive contribution to the tr...
# 24   Isidor Isaac Rabi (/ˈrɑːbi/; born Israel Isaac...
# 25   Root was a leading lawyer, whose clients inclu...
# 26   Albert Abraham Michelson FFRS HFRSE (December ...
# 27   Theodore  Roosevelt Jr. (/ˈroʊzəvɛlt/ ROH-zə-v...
# 28   Lê Đức Thọ (Vietnamese: [lē ɗɨ̌k tʰɔ̂ˀ] (liste...
# 29   Karman gained prominence in her country after ...
# ..                                                 ...
# 890  Barry James Marshall, AC, FRACP, FRS, FAA (bor...
# 891  John Robin Warren AC (born 11 June 1937 in Ade...
# 892  Peter Charles Doherty, FRS AC FMedSci (born 15...
# 893  Patrick Victor Martindale White (28 May 1912 –...
# 894  Alice Ann Munro (/ˈælɪs ˌæn mʌnˈroʊ/, née Laid...
# 895
# 896  Robert Alexander Mundell, CC (born October 24,...
# 897
# 898  Sir John Carew Eccles AC FRS FRACP FRSNZ FAA (...
# 899  Sir Frank Macfarlane Burnet, OM AK KBE FRS FAA...
# 900  Howard Walter Florey, Baron Florey, OM, FRS, F...
# 901  Elfriede Jelinek (German: [ɛlˈfʁiːdə ˈjɛlinɛk]...
# 902  Kandel, who had studied psychoanalysis, wanted...
# 903
# 904
# 905  Maurice Polydore Marie Bernard Maeterlinck (al...
# 906  Auguste Marie François Beernaert (26 July 1829...
# 907
# 908  Christian René Marie Joseph, Viscount de Duve ...
# 909  Claude served as director at Jules Bordet Inst...
# 910
# 911  Heymans won the Nobel Prize for Physiology or ...
# 912  Donna Theo Strickland (born 27 May 1959) is a ...
# 913
# 914
# 915  Muhammad Yunus (Bengali: মুহাম্মদ ইউনূস; born ...
# 916  He is Professor emeritus at the Université lib...
# 917
# 918  Lorenz studied instinctive behavior in animals...
# 919
#
#                                                 name  \
# 0                                Victor Francis Hess
# 1                                  Erwin Schrödinger
# 2                                         Max Perutz
# 3                                     Wolfgang Pauli
# 4                                    Niels Kaj Jerne
# 5                     Johannes Diderik van der Waals
# 6                                        Aziz Sancar
# 7                                        Orhan Pamuk
# 8                                    Georges Charpak
# 9                              Francis William Aston
# 10                                   Frederick Soddy
# 11                                 Winston Churchill
# 12                                      John L. Hall
# 13                                    Roy J. Glauber
# 14                                Edward C. Prescott
# 15                                        Irwin Rose
# 16                                    Charles K. Kao
# 17                                   George E. Smith
# 18                               Elizabeth Blackburn
# 19                                  Carol W. Greider
# 20                                     Toni Morrison
# 21                                 Robert Schrieffer
# 22                                    Gerald Edelman
# 23                                     Simon Kuznets
# 24                                 Isidor Isaac Rabi
# 25                                        Elihu Root
# 26                               Albert A. Michelson
# 27                                Theodore Roosevelt
# 28                                        Lê Đức Thọ
# 29                                   Tawakkol Karman
# ..                                               ...
# 890                                   Barry Marshall
# 891                                  J. Robin Warren
# 892  Peter C. Doherty  & Professor  Rolf Zinkernagel
# 893                                    Patrick White
# 894                                      Alice Munro
# 895                                  Jack W. Szostak
# 896                                   Robert Mundell
# 897                               Bertram Brockhouse
# 898                                John Carew Eccles
# 899                      Sir Frank Macfarlane Burnet
# 900                                    Howard Florey
# 901                                 Elfriede Jelinek
# 902                                      Eric Kandel
# 903                                     Jules Bordet
# 904                                Henri La Fontaine
# 905                              Maurice Maeterlinck
# 906                                Auguste Beernaert
# 907                                   Ilya Prigogine
# 908                                Christian de Duve
# 909                                    Albert Claude
# 910                                   Dominique Pire
# 911                                Corneille Heymans
# 912                                 Donna Strickland
# 913                               Arthur B. McDonald
# 914                              Svetlana Alexievich
# 915                                   Muhammad Yunus
# 916                                 François Englert
# 917                               Bertha von Suttner
# 918                                    Konrad Lorenz
# 919                             Alfred Hermann Fried
#
#                                         place_of_birth     place_of_death  \
# 0                                     Deutschfeistritz       Mount Vernon
# 1                                               Vienna             Vienna
# 2                                               Vienna          Cambridge
# 3                                               Vienna             Zürich
# 4                                               London  Castillon-du-Gard
# 5                                               Leiden          Amsterdam
# 6                                                Savur               None
# 7                                             Istanbul               None
# 8                                          Dubrovytsia              Paris
# 9                                             Harborne          Cambridge
# 10                                          Eastbourne           Brighton
# 11                                     Blenheim Palace     Hyde Park Gate
# 12                                              Denver               None
# 13                                       New York City               None
# 14                                         Glens Falls               None
# 15                                            Brooklyn          Deerfield
# 16                                            Shanghai            Sha Tin
# 17                                        White Plains               None
# 18                                              Hobart               None
# 19                                           San Diego               None
# 20                                       New York City               None
# 21                                            Oak Park               None
# 22                                              Queens           La Jolla
# 23                                               Pinsk          Cambridge
# 24                                             Rymanów      New York City
# 25                                             Clinton      New York City
# 26                                            Strzelno           Pasadena
# 27   Theodore Roosevelt Birthplace National Histori...         Oyster Bay
# 28                                              Hà Nam              Hanoi
# 29                                              Ta'izz               None
# ..                                                 ...                ...
# 890                                         Kalgoorlie               None
# 891                                           Adelaide               None
# 892                                           Brisbane               None
# 893                                             London             Sydney
# 894                                            Wingham               None
# 895                                             London               None
# 896                                           Kingston               None
# 897                                         Lethbridge           Hamilton
# 898                                          Melbourne            Locarno
# 899                                          Traralgon          Melbourne
# 900                                           Adelaide             Oxford
# 901                                       Mürzzuschlag               None
# 902                                             Vienna               None
# 903                                           Soignies           Brussels
# 904                                           Brussels           Brussels
# 905                                              Ghent               Nice
# 906                                             Ostend            Lucerne
# 907                                             Moscow           Brussels
# 908                                      Thames Ditton       Grez-Doiceau
# 909                                        Neufchâteau           Brussels
# 910                                             Dinant             Leuven
# 911                                              Ghent       Knokke-Heist
# 912                                             Guelph               None
# 913                                             Sydney               None
# 914                                    Ivano-Frankivsk               None
# 915                                         Chittagong               None
# 916                                          Etterbeek               None
# 917                                             Prague             Vienna
# 918                                             Vienna             Vienna
# 919                                             Vienna             Vienna
#
#                                                   text    year
# 0                  Victor Francis Hess , Physics, 1936  1936.0
# 1                    Erwin Schrödinger , Physics, 1933  1933.0
# 2                         Max Perutz , Chemistry, 1962  1962.0
# 3                       Wolfgang Pauli , Physics, 1945  1945.0
# 4       Niels Kaj Jerne , Physiology or Medicine, 1984  1984.0
# 5       Johannes Diderik van der Waals , Physics, 1910  1910.0
# 6                        Aziz Sancar , Chemistry, 2015  2015.0
# 7                       Orhan Pamuk , Literature, 2006  2006.0
# 8                      Georges Charpak , Physics, 1992  1992.0
# 9              Francis William Aston , Chemistry, 1922  1922.0
